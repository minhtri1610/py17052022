# %%
import pandas as pd
import seaborn as sns
from numpy import count_nonzero
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dulieuxettuyendaihoc.csv', header = 0, delimiter=',', encoding='unicode_escape')
# print(df.to_string())
df
# Out:
#     STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...   X6   D6   N6  GT  \
# 0     1  7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  ...  6.6  7.6  5.9   F
# 1     2  5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  ...  6.6  6.1  4.4   M
# 2     3  5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...  7.9  8.1  4.6   M
# 3     4  6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  ...  7.1  7.3  7.4   M
# 4     5  6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  ...  6.1  7.5  7.2   M
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ..
# 95   96  8.6  6.9  7.4  8.8  7.6  5.8  7.3  5.7  8.9  ...  6.3  6.1  6.2   F
# 96   97  3.7  5.4  6.0  5.1  5.5  3.9  6.1  4.4  4.1  ...  7.9  7.5  4.4   F
# 97   98  8.8  5.5  7.4  7.7  6.2  7.3  8.1  4.5  9.5  ...  9.6  8.4  5.8   M
# 98   99  2.7  1.8  3.4  5.3  4.5  7.9  4.9  3.8  2.8  ...  6.6  5.2  5.9   M
# 99  100  4.1  5.2  4.9  5.3  5.5  5.4  7.2  5.4  4.4  ...  5.6  6.6  5.8   M
#
#     DT   KV   DH1   DH2   DH3  KT
# ...

# %%
df[['T1', 'T2', 'T3', 'T4','T5', 'T6', 'DH1', 'DH2', 'DH3']].corr()
# Out:
#            T1        T2        T3        T4        T5        T6       DH1  \
# T1   1.000000  0.745750  0.585319  0.520067  0.592798  0.519035  0.049254
# T2   0.745750  1.000000  0.641550  0.649281  0.570521  0.566116  0.120347
# T3   0.585319  0.641550  1.000000  0.716712  0.657270  0.585507  0.088651
# T4   0.520067  0.649281  0.716712  1.000000  0.663908  0.595900 -0.039854
# T5   0.592798  0.570521  0.657270  0.663908  1.000000  0.778683  0.019512
# T6   0.519035  0.566116  0.585507  0.595900  0.778683  1.000000 -0.033360
# DH1  0.049254  0.120347  0.088651 -0.039854  0.019512 -0.033360  1.000000
# DH2  0.150497  0.143031  0.063597  0.121606  0.184647  0.301490  0.035154
# DH3  0.093952  0.182985  0.130094  0.133606  0.026830  0.045638  0.018731
#
#           DH2       DH3
# T1   0.150497  0.093952
# T2   0.143031  0.182985
# T3   0.063597  0.130094
# T4   0.121606  0.133606
# T5   0.184647  0.026830
# T6   0.301490  0.045638
# DH1  0.035154  0.018731
# DH2  1.000000 -0.091523
# ...

# %%
df[['T5', 'T6']].corr()
# Out:
#           T5        T6
# T5  1.000000  0.778683
# T6  0.778683  1.000000

# %%
# Với bàii toán phân tích hồi quy tuyến tính 2 biến
# Trước khi phân tích ta cần kiểm tra tương quan tuyến tính, nếu tương quan trên > 0.5 thì ta sẵn sàng nghiên cứu, nếu dưới 0.5 cần cân nhắc phương pháp khác

# %%
# Hãy dự báo điểm thi học kì 2 của năm lớp 12(t6) dựa trên điểm toán hk1 năm lớp 12(t5)

# %%
# đi tìm kiếm hàm f sao cho t6 = f(t5)
# có rất nhiều lớp hàm f, để tìm các hàm đó ta sẽ sử dụng AI để tìm
# ở bài toán này ta tiếp cận mô hình AI cơ bản để tìm hàm f với lớp hàm hồi quy tuyến tính đơn giản

# t5 -> input
# t6 -> output

# Model simple linear regression

# Y = f(x) = Ax + B + epsilon

# A: coff
# B: interception
# epsilon: sai số, (residual)

# Áp dụng vào bài toán ta có T6 = A*T5 + B + epsilon

# để tìm A và B ta cần dữ liệu historical data

# Mục đích của Machine leaning là đi tìm A và B dựa trên dữ liệu historical

# %%
df = df[['T5', 'T6']]

# %%
df
# Out:
#      T5   T6
# 0   7.4  6.9
# 1   3.0  4.0
# 2   4.8  5.7
# 3   6.1  7.4
# 4   6.8  8.0
# ..  ...  ...
# 95  7.9  6.6
# 96  5.5  5.7
# 97  9.0  8.5
# 98  4.1  4.3
# 99  5.6  5.1
#
# [100 rows x 2 columns]

# %%
df.corr()
# Out:
#           T5        T6
# T5  1.000000  0.778683
# T6  0.778683  1.000000

# %%
sns.pairplot(df, diag_kind='kde')
plt.show()

# %%
# Nhận xét: do T5, T6 có phân phối gần chuẩn và biểu đồ scatter của (t5, T6) các điểm tương quan như xung quanh đường thẳng, cho nên mô hình simple linear regression có khả năng áp dụng tốt cho bài toán dự báo t5, t6

# %%
# SV tự kiểm tra dữ liệu để áp dụng loại mô hình dựa trên các thông số corr, skewness, kutorsis

# %%
# Kiểm tra ngoại vi
plt.boxplot(df[['T5', 'T6']])
plt.show()

# %%
# Xây dựng mô hình trí tuệ nhân tạo (AI) sử dụng machine learning (ML)
# Khi xây dựng mô hình ML ta thưognf chia tập dữ liệu thành 2 phần, 
# 1. Training data:  tập huấn luyện cho mô hình
# 2. Testing data: tập kiểm thử
# SV cần hiểu được, tại sao phải chia dữ liệu ra làm 2 phần trainig và test. Từ đó hiêud được khái niệm overfiting( học vẹt )

# %%
# Tập dữ liệu
X = df[['T5']].values
y = df[['T6']].values
# Chia ra làm 2 phần(train và test0), giả sử tý lệ là 0.8 và 06
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)
y_train
# Out:
# array([[6. ],
#        [7.5],
#        [7.4],
#        [9. ],
#        [7.1],
#        [7.9],
#        [5.3],
#        [5.1],
#        [7.3],
#        [7.5],
#        [7.6],
#        [9.3],
#        [8.5],
#        [8.1],
#        [6.5],
#        [5.6],
#        [8.5],
#        [8.7],
#        [6.6],
#        [8.5],
#        [4. ],
#        [8.9],
#        [5.5],
#        [8.5],
#        [8. ],
#        [5.3],
#        [7.3],
#        [7.5],
#        [5.8],
#        [7.8],
#        [9.4],
#        [4.9],
#        [6.9],
#        [7. ],
#        [8.4],
#        [7.7],
#        [8.1],
#        [6.9],
#        [6.1],
#        [5.9],
#        [7.3],
#        [8. ],
#        [5.9],
#        [6.4],
#        [6.6],
#        [6.9],
#        [6.7],
#        [8.6],
#        [8.5],
#        [7.2],
#        [8.9],
#        [6.1],
#        [7.6],
#        [8.5],
#        [4.3],
#        [5.6],
#        [8.4],
#        [6.7],
#        [6.1],
#        [7.8],
#        [3.7],
#        [3.7],
# ...

# %%
from sklearn import linear_model

model=linear_model.LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[0.68598423]])

# %%
model.intercept_
# Out:
# array([2.41591707])

# %%
# Mo hinh

# T6 = 0.68... *T5 + 2.41 + epsilon

# %%
# Có rất nhiều phương pháp đánh giá mô hình

# %%
print('score:', model.score(X_train, y_train))
print('score:', model.score(X_test, y_test))
# Out:
# score: 0.5733390281169528
# score: 0.6215905656426834

# %%
# Xây dựng chương trình dự báo:
xT5 = float(input('Nhập điểm toán hk1 năm lớp 12'))
yT6 = model.predict([[xT5]])

print(f'dự báo điểm toán học kì 2 lớp 12 là {yT6}')
# Out:
# dự báo điểm toán học kì 2 lớp 12 là [[10.64772784]]
